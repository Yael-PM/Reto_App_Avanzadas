# %% [markdown]
# # Tests: función `preprocesamiento`

# %%
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "ftfy", "pandas", "numpy", "-q"])
# Out:
# 0

# %%
import unittest
import pandas as pd
import numpy as np
import ftfy
import re

# Función bajo prueba
def preprocesamiento(texto):
    if pd.isna(texto) or not isinstance(texto, str):
        return ""
    texto = ftfy.fix_text(texto)
    texto = re.sub(r'https?://\S+|www\.\S+', '', texto)
    texto = re.sub(r'@\w+', '', texto)
    texto = re.sub(r'[^\w\s.,!?¡¿]', '', texto)
    texto = texto.replace('\n', ' ').replace('\r', '')
    texto = re.sub(r'\s+', ' ', texto)
    return texto.strip().lower()

# %% [markdown]
# ## Suite 1 — Entradas vacías o inválidas

# %%
class TestEntradaInvalida(unittest.TestCase):

    def test_nan_retorna_cadena_vacia(self):
        self.assertEqual(preprocesamiento(float('nan')), "")

    def test_none_retorna_cadena_vacia(self):
        self.assertEqual(preprocesamiento(None), "")

    def test_entero_retorna_cadena_vacia(self):
        self.assertEqual(preprocesamiento(42), "")

    def test_lista_retorna_cadena_vacia(self):
        self.assertEqual(preprocesamiento(["hola"]), "")

    def test_cadena_vacia_retorna_cadena_vacia(self):
        self.assertEqual(preprocesamiento(""), "")


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.003s
#
# OK

# %% [markdown]
# ## Suite 2 — Corrección de Mojibake (ftfy)

# %%
class TestMojibake(unittest.TestCase):

    def test_tilde_corrupta_se_corrige(self):
        # 'Ã¡' es la codificación mojibake de 'á'
        resultado = preprocesamiento("EstÃ¡ bien")
        self.assertIn("está bien", resultado)

    def test_enie_corrupta_se_corrige(self):
        # 'Ã\xb1' es mojibake de 'ñ'
        resultado = preprocesamiento("espaÃ\xb1ol")
        self.assertIn("español", resultado)

    def test_texto_limpio_no_se_altera(self):
        resultado = preprocesamiento("texto limpio")
        self.assertEqual(resultado, "texto limpio")


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.003s
#
# OK

# %% [markdown]
# ## Suite 3 — Eliminación de URLs

# %%
class TestEliminacionURLs(unittest.TestCase):

    def test_url_http_eliminada(self):
        resultado = preprocesamiento("mira esto http://ejemplo.com increíble")
        self.assertNotIn("http", resultado)
        self.assertIn("increíble", resultado)

    def test_url_https_eliminada(self):
        resultado = preprocesamiento("visita https://ejemplo.com/articulo")
        self.assertNotIn("https", resultado)

    def test_url_www_eliminada(self):
        resultado = preprocesamiento("ver www.ejemplo.com para más info")
        self.assertNotIn("www", resultado)

    def test_texto_sin_url_no_cambia(self):
        resultado = preprocesamiento("hola mundo")
        self.assertEqual(resultado, "hola mundo")


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
#
# ----------------------------------------------------------------------
# Ran 12 tests in 0.004s
#
# OK

# %% [markdown]
# ## Suite 4 — Eliminación de menciones (@usuario)

# %%
class TestEliminacionMenciones(unittest.TestCase):

    def test_mencion_simple_eliminada(self):
        resultado = preprocesamiento("hola @usuario como estás")
        self.assertNotIn("@usuario", resultado)
        self.assertIn("hola", resultado)

    def test_multiple_menciones_eliminadas(self):
        resultado = preprocesamiento("@user1 y @user2 se fueron")
        self.assertNotIn("@", resultado)
        self.assertIn("se fueron", resultado)

    def test_arroba_en_email_eliminada(self):
        # El regex elimina cualquier @palabra, incluyendo fragmentos de correos
        resultado = preprocesamiento("contacto en correo@dominio")
        self.assertNotIn("@dominio", resultado)


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
#
# ----------------------------------------------------------------------
# Ran 15 tests in 0.004s
#
# OK

# %% [markdown]
# ## Suite 5 — Preservación de puntuación clínica relevante

# %%
class TestPuntuacion(unittest.TestCase):

    def test_punto_se_preserva(self):
        resultado = preprocesamiento("No como. Nunca.")
        self.assertIn(".", resultado)

    def test_exclamacion_se_preserva(self):
        resultado = preprocesamiento("¡Qué hambre!")
        self.assertIn("!", resultado)

    def test_interrogacion_se_preserva(self):
        resultado = preprocesamiento("¿Por qué como tanto?")
        self.assertIn("?", resultado)
        self.assertIn("¿", resultado)

    def test_coma_se_preserva(self):
        resultado = preprocesamiento("hambre, sed, cansancio")
        self.assertIn(",", resultado)

    def test_emojis_eliminados(self):
        resultado = preprocesamiento("me siento mal 💔")
        self.assertNotIn("💔", resultado)

    def test_hashtag_elimina_simbolo_preserva_texto(self):
        # El # no está en el conjunto permitido, pero las letras sí
        resultado = preprocesamiento("#HastaLosHuesos es una etiqueta")
        self.assertNotIn("#", resultado)
        self.assertIn("hastaloshuesos", resultado)


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
#
# ----------------------------------------------------------------------
# Ran 21 tests in 0.007s
#
# OK

# %% [markdown]
# ## Suite 6 — Normalización de espacios y saltos de línea

# %%
class TestEspacios(unittest.TestCase):

    def test_salto_de_linea_reemplazado_por_espacio(self):
        resultado = preprocesamiento("hola\nmundo")
        self.assertNotIn("\n", resultado)
        self.assertIn("hola mundo", resultado)

    def test_retorno_de_carro_eliminado(self):
        resultado = preprocesamiento("hola\rmundo")
        self.assertNotIn("\r", resultado)

    def test_espacios_multiples_colapsados(self):
        resultado = preprocesamiento("hola    mundo")
        self.assertEqual(resultado, "hola mundo")

    def test_espacios_al_inicio_y_fin_eliminados(self):
        resultado = preprocesamiento("  hola mundo  ")
        self.assertEqual(resultado, "hola mundo")


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
#
# ----------------------------------------------------------------------
# Ran 25 tests in 0.007s
#
# OK

# %% [markdown]
# ## Suite 7 — Conversión a minúsculas

# %%
class TestMinusculas(unittest.TestCase):

    def test_mayusculas_convertidas(self):
        resultado = preprocesamiento("ANOREXIA")
        self.assertEqual(resultado, "anorexia")

    def test_mixto_convertido(self):
        resultado = preprocesamiento("No Como Nada")
        self.assertEqual(resultado, "no como nada")

    def test_ya_minusculas_no_cambia(self):
        resultado = preprocesamiento("todo en minúsculas")
        self.assertEqual(resultado, "todo en minúsculas")


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
#
# ----------------------------------------------------------------------
# Ran 28 tests in 0.008s
#
# OK

# %% [markdown]
# ## Suite 8 — Casos reales del dataset (tweets con Mojibake)

# %%
class TestCasosRealesDataset(unittest.TestCase):

    def test_tweet_mojibake_azucar(self):
        # Ejemplo real del dataset: 'azÃºcar' → 'azúcar'
        resultado = preprocesamiento("Cheesecake saludable sin azÃºcar y sin lactosa")
        self.assertIn("azúcar", resultado)
        self.assertNotIn("azÃºcar", resultado)

    def test_tweet_mojibake_frio(self):
        # 'frÃ­o' → 'frío'
        resultado = preprocesamiento("no sentÃ­a mi cuerpo tan frÃ­o")
        self.assertIn("frío", resultado)

    def test_tweet_con_hashtag_y_emoji(self):
        resultado = preprocesamiento("ser como ellas ♡♡\n  #HastaLosHuesos")
        self.assertNotIn("♡", resultado)
        self.assertNotIn("#", resultado)
        self.assertNotIn("\n", resultado)
        self.assertIn("hastaloshuesos", resultado)


unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
#
# ----------------------------------------------------------------------
# Ran 31 tests in 0.010s
#
# OK

# %% [markdown]
# ---
# ## Nuevas funciones — `segmentar_y_normalizar_v2` · `tokenizar_lematizar` · `fitness_function`
#
# Pruebas para las tres funciones añadidas al clasificador tras la refactorización.

# %%
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "wordsegment", "-q"])
subprocess.check_call([sys.executable, "-m", "spacy", "download", "es_core_news_sm", "--quiet"])
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# 0

# %%
import numpy as np
import spacy
from wordsegment import load, segment
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score

load()

dict_slang = {
    "ntp": "no te preocupes", "pq": "porque", "x q": "porque",
    "tkm": "te quiero mucho", "d": "de", "q": "que", "toy": "estoy",
    "chi": "si", "x": "por", "k": "que", "salu2": "saludos",
    "bno": "bueno", "ño": "no", "onde": "donde", "tmb": "también",
    "akiora": "a que hora", "aquiora": "a que hora", "shi": "si",
    "xq": "porque", "xk": "porque"
}

def segmentar_normalizar(texto):
    if not texto: return ""
    palabras = texto.split()
    texto_procesado = []
    for p in palabras:
        p_limpia = p.replace('#', '').lower()
        if p_limpia in dict_slang:
            texto_procesado.append(dict_slang[p_limpia])
        elif p.startswith('#') and len(p_limpia) > 5:
            seg = segment(p_limpia)
            if len(seg) < 4:
                texto_procesado.extend(seg)
            else:
                texto_procesado.append(p_limpia)
        else:
            texto_procesado.append(p)
    return " ".join(texto_procesado)

_nlp = spacy.load("es_core_news_sm")

def tokenizar_lematizar(texto):
    if not texto: return ""
    doc = _nlp(texto)
    return " ".join(token.lemma_ for token in doc)

f1_anorexia = make_scorer(f1_score, pos_label='anorexia')

def fitness_function(ga_instance, solution, solution_idx):
    sol = np.array(solution).flatten()
    if np.sum(sol) == 0:
        return 0.0
    try:
        X_reducida = X[:, sol == 1]
        modelo = LogisticRegression(max_iter=1000, class_weight='balanced', solver='liblinear')
        scores = cross_val_score(modelo, X_reducida, y, cv=5, scoring=f1_anorexia)
        return float(scores.mean())
    except Exception:
        return 0.0

# %% [markdown]
# ## Suite 9 — `segmentar_y_normalizar_v2`: entradas vacías o inválidas

# %%
class TestSegmentarEntradaInvalida(unittest.TestCase):

    def test_cadena_vacia_retorna_vacia(self):
        self.assertEqual(segmentar_y_normalizar_v2(""), "")

    def test_none_retorna_vacia(self):
        self.assertEqual(segmentar_y_normalizar_v2(None), "")

unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ----------------------------------------------------------------------
# Ran 33 tests in 0.012s
#
# FAILED (errors=2)

# %% [markdown]
# ## Suite 10 — `segmentar_y_normalizar_v2`: expansión de slang

# %%
class TestSegmentarSlang(unittest.TestCase):

    def test_xq_expandido(self):
        resultado = segmentar_y_normalizar_v2("xq no comiste")
        self.assertIn("porque", resultado)
        self.assertNotIn("xq", resultado)

    def test_tmb_expandido(self):
        resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
        self.assertIn("también", resultado)
        self.assertNotIn("tmb", resultado)

    def test_tkm_expandido(self):
        resultado = segmentar_y_normalizar_v2("tkm")
        self.assertEqual(resultado, "te quiero mucho")

    def test_slang_insensible_a_mayusculas(self):
        # p_limpia aplica .lower(), así que "XQ" debe expandirse igual que "xq"
        resultado = segmentar_y_normalizar_v2("XQ lloras")
        self.assertIn("porque", resultado)

    def test_salu2_expandido(self):
        resultado = segmentar_y_normalizar_v2("salu2 a todos")
        self.assertIn("saludos", resultado)

unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido) ... ERROR
# test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas) ... ERROR
# test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido) ... ERROR
# test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido) ... ERROR
# test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 23, in test_salu2_expandido
#     resultado = segmentar_y_normalizar_v2("salu2 a todos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 19, in test_slang_insensible_a_mayusculas
#     resultado = segmentar_y_normalizar_v2("XQ lloras")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 14, in test_tkm_expandido
#     resultado = segmentar_y_normalizar_v2("tkm")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 9, in test_tmb_expandido
#     resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 4, in test_xq_expandido
#     resultado = segmentar_y_normalizar_v2("xq no comiste")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ----------------------------------------------------------------------
# Ran 38 tests in 0.014s
#
# FAILED (errors=7)

# %% [markdown]
# ## Suite 11 — `segmentar_y_normalizar_v2`: segmentación de hashtags

# %%
class TestSegmentarHashtag(unittest.TestCase):

    def test_hashtag_largo_produce_multiples_tokens(self):
        # "#hastaloshuesos" (14 chars) debe segmentarse en varias palabras
        resultado = segmentar_y_normalizar_v2("#hastaloshuesos")
        self.assertNotIn("#", resultado)
        self.assertGreater(len(resultado.split()), 1)

    def test_simbolo_hashtag_eliminado(self):
        resultado = segmentar_y_normalizar_v2("#proanorexia")
        self.assertNotIn("#", resultado)

    def test_hashtag_mayusculas_normalizado(self):
        # "#HastaLosHuesos" → segmentación en minúsculas sin #
        resultado = segmentar_y_normalizar_v2("#HastaLosHuesos")
        self.assertNotIn("#", resultado)
        self.assertEqual(resultado, resultado.lower())

    def test_hashtag_corto_no_segmentado(self):
        # "#ana" (3 chars) ≤ 5, no entra en la rama de segmentación
        resultado = segmentar_y_normalizar_v2("#ana")
        self.assertIn("ana", resultado)

unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado) ... ERROR
# test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens) ... ERROR
# test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado) ... ERROR
# test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado) ... ERROR
# test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido) ... ERROR
# test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas) ... ERROR
# test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido) ... ERROR
# test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido) ... ERROR
# test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 21, in test_hashtag_corto_no_segmentado
#     resultado = segmentar_y_normalizar_v2("#ana")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 5, in test_hashtag_largo_produce_multiples_tokens
#     resultado = segmentar_y_normalizar_v2("#hastaloshuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 15, in test_hashtag_mayusculas_normalizado
#     resultado = segmentar_y_normalizar_v2("#HastaLosHuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 10, in test_simbolo_hashtag_eliminado
#     resultado = segmentar_y_normalizar_v2("#proanorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 23, in test_salu2_expandido
#     resultado = segmentar_y_normalizar_v2("salu2 a todos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 19, in test_slang_insensible_a_mayusculas
#     resultado = segmentar_y_normalizar_v2("XQ lloras")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 14, in test_tkm_expandido
#     resultado = segmentar_y_normalizar_v2("tkm")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 9, in test_tmb_expandido
#     resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 4, in test_xq_expandido
#     resultado = segmentar_y_normalizar_v2("xq no comiste")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ----------------------------------------------------------------------
# Ran 42 tests in 0.015s
#
# FAILED (errors=11)

# %% [markdown]
# ## Suite 12 — `segmentar_y_normalizar_v2`: palabras normales sin transformación

# %%
class TestSegmentarPalabrasNormales(unittest.TestCase):

    def test_palabras_sin_hashtag_ni_slang_sin_cambio(self):
        resultado = segmentar_y_normalizar_v2("comer hoy aquí")
        self.assertEqual(resultado, "comer hoy aquí")

    def test_multiples_palabras_normales(self):
        resultado = segmentar_y_normalizar_v2("no quiero comer nada")
        self.assertEqual(resultado, "no quiero comer nada")

    def test_mezcla_slang_y_normales(self):
        resultado = segmentar_y_normalizar_v2("xq no como")
        self.assertIn("porque", resultado)
        self.assertIn("como", resultado)

unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado) ... ERROR
# test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens) ... ERROR
# test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado) ... ERROR
# test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado) ... ERROR
# test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales) ... ERROR
# test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales) ... ERROR
# test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio) ... ERROR
# test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido) ... ERROR
# test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas) ... ERROR
# test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido) ... ERROR
# test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido) ... ERROR
# test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 21, in test_hashtag_corto_no_segmentado
#     resultado = segmentar_y_normalizar_v2("#ana")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 5, in test_hashtag_largo_produce_multiples_tokens
#     resultado = segmentar_y_normalizar_v2("#hastaloshuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 15, in test_hashtag_mayusculas_normalizado
#     resultado = segmentar_y_normalizar_v2("#HastaLosHuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 10, in test_simbolo_hashtag_eliminado
#     resultado = segmentar_y_normalizar_v2("#proanorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 12, in test_mezcla_slang_y_normales
#     resultado = segmentar_y_normalizar_v2("xq no como")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 8, in test_multiples_palabras_normales
#     resultado = segmentar_y_normalizar_v2("no quiero comer nada")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 4, in test_palabras_sin_hashtag_ni_slang_sin_cambio
#     resultado = segmentar_y_normalizar_v2("comer hoy aquí")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 23, in test_salu2_expandido
#     resultado = segmentar_y_normalizar_v2("salu2 a todos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 19, in test_slang_insensible_a_mayusculas
#     resultado = segmentar_y_normalizar_v2("XQ lloras")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 14, in test_tkm_expandido
#     resultado = segmentar_y_normalizar_v2("tkm")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 9, in test_tmb_expandido
#     resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 4, in test_xq_expandido
#     resultado = segmentar_y_normalizar_v2("xq no comiste")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ----------------------------------------------------------------------
# Ran 45 tests in 0.017s
#
# FAILED (errors=14)

# %% [markdown]
# ## Suite 13 — `tokenizar_y_lematizar`: entradas vacías o inválidas

# %%
class TestTokenizarEntradaInvalida(unittest.TestCase):

    def test_cadena_vacia_retorna_vacia(self):
        self.assertEqual(tokenizar_y_lematizar(""), "")

    def test_none_retorna_vacia(self):
        self.assertEqual(tokenizar_y_lematizar(None), "")

unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado) ... ERROR
# test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens) ... ERROR
# test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado) ... ERROR
# test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado) ... ERROR
# test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales) ... ERROR
# test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales) ... ERROR
# test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio) ... ERROR
# test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido) ... ERROR
# test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas) ... ERROR
# test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido) ... ERROR
# test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido) ... ERROR
# test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido) ... ERROR
# test_cadena_vacia_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_none_retorna_vacia) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 21, in test_hashtag_corto_no_segmentado
#     resultado = segmentar_y_normalizar_v2("#ana")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 5, in test_hashtag_largo_produce_multiples_tokens
#     resultado = segmentar_y_normalizar_v2("#hastaloshuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 15, in test_hashtag_mayusculas_normalizado
#     resultado = segmentar_y_normalizar_v2("#HastaLosHuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 10, in test_simbolo_hashtag_eliminado
#     resultado = segmentar_y_normalizar_v2("#proanorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 12, in test_mezcla_slang_y_normales
#     resultado = segmentar_y_normalizar_v2("xq no como")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 8, in test_multiples_palabras_normales
#     resultado = segmentar_y_normalizar_v2("no quiero comer nada")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 4, in test_palabras_sin_hashtag_ni_slang_sin_cambio
#     resultado = segmentar_y_normalizar_v2("comer hoy aquí")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 23, in test_salu2_expandido
#     resultado = segmentar_y_normalizar_v2("salu2 a todos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 19, in test_slang_insensible_a_mayusculas
#     resultado = segmentar_y_normalizar_v2("XQ lloras")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 14, in test_tkm_expandido
#     resultado = segmentar_y_normalizar_v2("tkm")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 9, in test_tmb_expandido
#     resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 4, in test_xq_expandido
#     resultado = segmentar_y_normalizar_v2("xq no comiste")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1265208303.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(tokenizar_y_lematizar(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1265208303.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(tokenizar_y_lematizar(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ----------------------------------------------------------------------
# Ran 47 tests in 0.016s
#
# FAILED (errors=16)

# %% [markdown]
# ## Suite 14 — `tokenizar_y_lematizar`: lematización con spaCy

# %%
class TestTokenizarLematizacion(unittest.TestCase):

    def test_verbo_conjugado_lematizado(self):
        # "comiendo" debe dar lema "comer"
        resultado = tokenizar_y_lematizar("comiendo")
        self.assertIn("comer", resultado)

    def test_plural_lematizado(self):
        # "huesos" debe dar lema "hueso"
        resultado = tokenizar_y_lematizar("huesos")
        self.assertIn("hueso", resultado)

    def test_resultado_es_string(self):
        resultado = tokenizar_y_lematizar("tengo hambre")
        self.assertIsInstance(resultado, str)

    def test_lemas_en_minusculas_para_entrada_minuscula(self):
        resultado = tokenizar_y_lematizar("comer")
        self.assertEqual(resultado, resultado.lower())

    def test_texto_no_vacio_produce_salida_no_vacia(self):
        resultado = tokenizar_y_lematizar("anorexia")
        self.assertGreater(len(resultado), 0)

unittest.main(argv=[''], exit=False, verbosity=2)
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado) ... ERROR
# test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens) ... ERROR
# test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado) ... ERROR
# test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado) ... ERROR
# test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales) ... ERROR
# test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales) ... ERROR
# test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio) ... ERROR
# test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido) ... ERROR
# test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas) ... ERROR
# test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido) ... ERROR
# test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido) ... ERROR
# test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido) ... ERROR
# test_cadena_vacia_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_lemas_en_minusculas_para_entrada_minuscula (__main__.TestTokenizarLematizacion.test_lemas_en_minusculas_para_entrada_minuscula) ... ERROR
# test_plural_lematizado (__main__.TestTokenizarLematizacion.test_plural_lematizado) ... ERROR
# test_resultado_es_string (__main__.TestTokenizarLematizacion.test_resultado_es_string) ... ERROR
# test_texto_no_vacio_produce_salida_no_vacia (__main__.TestTokenizarLematizacion.test_texto_no_vacio_produce_salida_no_vacia) ... ERROR
# test_verbo_conjugado_lematizado (__main__.TestTokenizarLematizacion.test_verbo_conjugado_lematizado) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 21, in test_hashtag_corto_no_segmentado
#     resultado = segmentar_y_normalizar_v2("#ana")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 5, in test_hashtag_largo_produce_multiples_tokens
#     resultado = segmentar_y_normalizar_v2("#hastaloshuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 15, in test_hashtag_mayusculas_normalizado
#     resultado = segmentar_y_normalizar_v2("#HastaLosHuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 10, in test_simbolo_hashtag_eliminado
#     resultado = segmentar_y_normalizar_v2("#proanorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 12, in test_mezcla_slang_y_normales
#     resultado = segmentar_y_normalizar_v2("xq no como")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 8, in test_multiples_palabras_normales
#     resultado = segmentar_y_normalizar_v2("no quiero comer nada")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 4, in test_palabras_sin_hashtag_ni_slang_sin_cambio
#     resultado = segmentar_y_normalizar_v2("comer hoy aquí")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 23, in test_salu2_expandido
#     resultado = segmentar_y_normalizar_v2("salu2 a todos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 19, in test_slang_insensible_a_mayusculas
#     resultado = segmentar_y_normalizar_v2("XQ lloras")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 14, in test_tkm_expandido
#     resultado = segmentar_y_normalizar_v2("tkm")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 9, in test_tmb_expandido
#     resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 4, in test_xq_expandido
#     resultado = segmentar_y_normalizar_v2("xq no comiste")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1265208303.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(tokenizar_y_lematizar(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1265208303.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(tokenizar_y_lematizar(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_lemas_en_minusculas_para_entrada_minuscula (__main__.TestTokenizarLematizacion.test_lemas_en_minusculas_para_entrada_minuscula)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 18, in test_lemas_en_minusculas_para_entrada_minuscula
#     resultado = tokenizar_y_lematizar("comer")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_plural_lematizado (__main__.TestTokenizarLematizacion.test_plural_lematizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 10, in test_plural_lematizado
#     resultado = tokenizar_y_lematizar("huesos")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_resultado_es_string (__main__.TestTokenizarLematizacion.test_resultado_es_string)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 14, in test_resultado_es_string
#     resultado = tokenizar_y_lematizar("tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_texto_no_vacio_produce_salida_no_vacia (__main__.TestTokenizarLematizacion.test_texto_no_vacio_produce_salida_no_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 22, in test_texto_no_vacio_produce_salida_no_vacia
#     resultado = tokenizar_y_lematizar("anorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_verbo_conjugado_lematizado (__main__.TestTokenizarLematizacion.test_verbo_conjugado_lematizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 5, in test_verbo_conjugado_lematizado
#     resultado = tokenizar_y_lematizar("comiendo")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ----------------------------------------------------------------------
# Ran 52 tests in 0.017s
#
# FAILED (errors=21)

# %% [markdown]
# ## Suite 15 — `fitness_function`: comportamiento con soluciones extremas

# %%
from sklearn.datasets import make_classification

# Datos sintéticos para aislar fitness_function de los datos reales del proyecto
_X_synth, _y_raw = make_classification(n_samples=30, n_features=6, random_state=0)
_y_synth = np.where(_y_raw == 1, 'anorexia', 'control')

_X_prev = globals().get('X', None)
_y_prev = globals().get('y', None)
X = _X_synth
y = _y_synth

class TestFitnessFunction(unittest.TestCase):

    def test_solucion_todo_ceros_retorna_cero(self):
        result = fitness_function(None, [0] * 6, 0)
        self.assertEqual(result, 0.0)

    def test_solucion_con_features_retorna_float(self):
        result = fitness_function(None, [1, 0, 1, 0, 1, 0], 0)
        self.assertIsInstance(result, float)

    def test_fitness_acotado_entre_0_y_1(self):
        result = fitness_function(None, [1] * 6, 0)
        self.assertGreaterEqual(result, 0.0)
        self.assertLessEqual(result, 1.0)

    def test_solucion_parcial_no_lanza_excepcion(self):
        # Aunque solo haya 1 feature seleccionada no debe explotar
        result = fitness_function(None, [0, 0, 0, 0, 0, 1], 0)
        self.assertIsInstance(result, float)

unittest.main(argv=[''], exit=False, verbosity=2)

if _X_prev is not None: X = _X_prev
if _y_prev is not None: y = _y_prev
# Out:
# test_tweet_con_hashtag_y_emoji (__main__.TestCasosRealesDataset.test_tweet_con_hashtag_y_emoji) ... ok
# test_tweet_mojibake_azucar (__main__.TestCasosRealesDataset.test_tweet_mojibake_azucar) ... ok
# test_tweet_mojibake_frio (__main__.TestCasosRealesDataset.test_tweet_mojibake_frio) ... ok
# test_arroba_en_email_eliminada (__main__.TestEliminacionMenciones.test_arroba_en_email_eliminada) ... ok
# test_mencion_simple_eliminada (__main__.TestEliminacionMenciones.test_mencion_simple_eliminada) ... ok
# test_multiple_menciones_eliminadas (__main__.TestEliminacionMenciones.test_multiple_menciones_eliminadas) ... ok
# test_texto_sin_url_no_cambia (__main__.TestEliminacionURLs.test_texto_sin_url_no_cambia) ... ok
# test_url_http_eliminada (__main__.TestEliminacionURLs.test_url_http_eliminada) ... ok
# test_url_https_eliminada (__main__.TestEliminacionURLs.test_url_https_eliminada) ... ok
# test_url_www_eliminada (__main__.TestEliminacionURLs.test_url_www_eliminada) ... ok
# test_cadena_vacia_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_cadena_vacia_retorna_cadena_vacia) ... ok
# test_entero_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_entero_retorna_cadena_vacia) ... ok
# test_lista_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_lista_retorna_cadena_vacia) ... ok
# test_nan_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_nan_retorna_cadena_vacia) ... ok
# test_none_retorna_cadena_vacia (__main__.TestEntradaInvalida.test_none_retorna_cadena_vacia) ... ok
# test_espacios_al_inicio_y_fin_eliminados (__main__.TestEspacios.test_espacios_al_inicio_y_fin_eliminados) ... ok
# test_espacios_multiples_colapsados (__main__.TestEspacios.test_espacios_multiples_colapsados) ... ok
# test_retorno_de_carro_eliminado (__main__.TestEspacios.test_retorno_de_carro_eliminado) ... ok
# test_salto_de_linea_reemplazado_por_espacio (__main__.TestEspacios.test_salto_de_linea_reemplazado_por_espacio) ... ok
# test_fitness_acotado_entre_0_y_1 (__main__.TestFitnessFunction.test_fitness_acotado_entre_0_y_1) ... ok
# test_solucion_con_features_retorna_float (__main__.TestFitnessFunction.test_solucion_con_features_retorna_float) ... ok
# test_solucion_parcial_no_lanza_excepcion (__main__.TestFitnessFunction.test_solucion_parcial_no_lanza_excepcion) ... ok
# test_solucion_todo_ceros_retorna_cero (__main__.TestFitnessFunction.test_solucion_todo_ceros_retorna_cero) ... ok
# test_mayusculas_convertidas (__main__.TestMinusculas.test_mayusculas_convertidas) ... ok
# test_mixto_convertido (__main__.TestMinusculas.test_mixto_convertido) ... ok
# test_ya_minusculas_no_cambia (__main__.TestMinusculas.test_ya_minusculas_no_cambia) ... ok
# test_enie_corrupta_se_corrige (__main__.TestMojibake.test_enie_corrupta_se_corrige) ... ok
# test_texto_limpio_no_se_altera (__main__.TestMojibake.test_texto_limpio_no_se_altera) ... ok
# test_tilde_corrupta_se_corrige (__main__.TestMojibake.test_tilde_corrupta_se_corrige) ... ok
# test_coma_se_preserva (__main__.TestPuntuacion.test_coma_se_preserva) ... ok
# test_emojis_eliminados (__main__.TestPuntuacion.test_emojis_eliminados) ... ok
# test_exclamacion_se_preserva (__main__.TestPuntuacion.test_exclamacion_se_preserva) ... ok
# test_hashtag_elimina_simbolo_preserva_texto (__main__.TestPuntuacion.test_hashtag_elimina_simbolo_preserva_texto) ... ok
# test_interrogacion_se_preserva (__main__.TestPuntuacion.test_interrogacion_se_preserva) ... ok
# test_punto_se_preserva (__main__.TestPuntuacion.test_punto_se_preserva) ... ok
# test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado) ... ERROR
# test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens) ... ERROR
# test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado) ... ERROR
# test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado) ... ERROR
# test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales) ... ERROR
# test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales) ... ERROR
# test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio) ... ERROR
# test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido) ... ERROR
# test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas) ... ERROR
# test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido) ... ERROR
# test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido) ... ERROR
# test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido) ... ERROR
# test_cadena_vacia_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_cadena_vacia_retorna_vacia) ... ERROR
# test_none_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_none_retorna_vacia) ... ERROR
# test_lemas_en_minusculas_para_entrada_minuscula (__main__.TestTokenizarLematizacion.test_lemas_en_minusculas_para_entrada_minuscula) ... ERROR
# test_plural_lematizado (__main__.TestTokenizarLematizacion.test_plural_lematizado) ... ERROR
# test_resultado_es_string (__main__.TestTokenizarLematizacion.test_resultado_es_string) ... ERROR
# test_texto_no_vacio_produce_salida_no_vacia (__main__.TestTokenizarLematizacion.test_texto_no_vacio_produce_salida_no_vacia) ... ERROR
# test_verbo_conjugado_lematizado (__main__.TestTokenizarLematizacion.test_verbo_conjugado_lematizado) ... ERROR
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestSegmentarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/3973196571.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(segmentar_y_normalizar_v2(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_corto_no_segmentado (__main__.TestSegmentarHashtag.test_hashtag_corto_no_segmentado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 21, in test_hashtag_corto_no_segmentado
#     resultado = segmentar_y_normalizar_v2("#ana")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_largo_produce_multiples_tokens (__main__.TestSegmentarHashtag.test_hashtag_largo_produce_multiples_tokens)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 5, in test_hashtag_largo_produce_multiples_tokens
#     resultado = segmentar_y_normalizar_v2("#hastaloshuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_hashtag_mayusculas_normalizado (__main__.TestSegmentarHashtag.test_hashtag_mayusculas_normalizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 15, in test_hashtag_mayusculas_normalizado
#     resultado = segmentar_y_normalizar_v2("#HastaLosHuesos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_simbolo_hashtag_eliminado (__main__.TestSegmentarHashtag.test_simbolo_hashtag_eliminado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/275217453.py", line 10, in test_simbolo_hashtag_eliminado
#     resultado = segmentar_y_normalizar_v2("#proanorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_mezcla_slang_y_normales (__main__.TestSegmentarPalabrasNormales.test_mezcla_slang_y_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 12, in test_mezcla_slang_y_normales
#     resultado = segmentar_y_normalizar_v2("xq no como")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_multiples_palabras_normales (__main__.TestSegmentarPalabrasNormales.test_multiples_palabras_normales)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 8, in test_multiples_palabras_normales
#     resultado = segmentar_y_normalizar_v2("no quiero comer nada")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_palabras_sin_hashtag_ni_slang_sin_cambio (__main__.TestSegmentarPalabrasNormales.test_palabras_sin_hashtag_ni_slang_sin_cambio)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/710811840.py", line 4, in test_palabras_sin_hashtag_ni_slang_sin_cambio
#     resultado = segmentar_y_normalizar_v2("comer hoy aquí")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_salu2_expandido (__main__.TestSegmentarSlang.test_salu2_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 23, in test_salu2_expandido
#     resultado = segmentar_y_normalizar_v2("salu2 a todos")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_slang_insensible_a_mayusculas (__main__.TestSegmentarSlang.test_slang_insensible_a_mayusculas)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 19, in test_slang_insensible_a_mayusculas
#     resultado = segmentar_y_normalizar_v2("XQ lloras")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tkm_expandido (__main__.TestSegmentarSlang.test_tkm_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 14, in test_tkm_expandido
#     resultado = segmentar_y_normalizar_v2("tkm")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_tmb_expandido (__main__.TestSegmentarSlang.test_tmb_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 9, in test_tmb_expandido
#     resultado = segmentar_y_normalizar_v2("tmb tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_xq_expandido (__main__.TestSegmentarSlang.test_xq_expandido)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1090108258.py", line 4, in test_xq_expandido
#     resultado = segmentar_y_normalizar_v2("xq no comiste")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'segmentar_y_normalizar_v2' is not defined. Did you mean: 'segmentar_normalizar'?
#
# ======================================================================
# ERROR: test_cadena_vacia_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_cadena_vacia_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1265208303.py", line 4, in test_cadena_vacia_retorna_vacia
#     self.assertEqual(tokenizar_y_lematizar(""), "")
#                      ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_none_retorna_vacia (__main__.TestTokenizarEntradaInvalida.test_none_retorna_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1265208303.py", line 7, in test_none_retorna_vacia
#     self.assertEqual(tokenizar_y_lematizar(None), "")
#                      ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_lemas_en_minusculas_para_entrada_minuscula (__main__.TestTokenizarLematizacion.test_lemas_en_minusculas_para_entrada_minuscula)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 18, in test_lemas_en_minusculas_para_entrada_minuscula
#     resultado = tokenizar_y_lematizar("comer")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_plural_lematizado (__main__.TestTokenizarLematizacion.test_plural_lematizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 10, in test_plural_lematizado
#     resultado = tokenizar_y_lematizar("huesos")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_resultado_es_string (__main__.TestTokenizarLematizacion.test_resultado_es_string)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 14, in test_resultado_es_string
#     resultado = tokenizar_y_lematizar("tengo hambre")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_texto_no_vacio_produce_salida_no_vacia (__main__.TestTokenizarLematizacion.test_texto_no_vacio_produce_salida_no_vacia)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 22, in test_texto_no_vacio_produce_salida_no_vacia
#     resultado = tokenizar_y_lematizar("anorexia")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ======================================================================
# ERROR: test_verbo_conjugado_lematizado (__main__.TestTokenizarLematizacion.test_verbo_conjugado_lematizado)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/41/qv7vy6q53nz7dkqkrsww7qm80000gn/T/ipykernel_40878/1579225746.py", line 5, in test_verbo_conjugado_lematizado
#     resultado = tokenizar_y_lematizar("comiendo")
#                 ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'tokenizar_y_lematizar' is not defined. Did you mean: 'tokenizar_lematizar'?
#
# ----------------------------------------------------------------------
# Ran 56 tests in 0.044s
#
# FAILED (errors=21)
